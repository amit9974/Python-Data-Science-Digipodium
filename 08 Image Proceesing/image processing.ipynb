# %%
from PIL import Image, ImageDraw, ImageFilter, ImageEnhance

# %%
im = Image.open('background.jpg')

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x399>

# %%
im.size
# Out:
# (700, 399)

# %%
im.mode
# Out:
# 'RGB'

# %%
im.format
im.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
im.show() # show in popup mode

# %%
thum = im.copy()
thum.thumbnail((160, 60))
thum # show 
thum.save("thumbnail.png")

# %%
im.resize((800, 400))
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>

# %%
hero = Image.open('hero.png')
hero
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=196x204>

# %%
w,h = hero.size
hero.resize((w*8, h*8), Image.Resampling.BILINEAR)
# Out:
# <PIL.Image.Image image mode=RGBA size=1568x1632>

# %%
# reduce size
hero.resize((w//2, h//2), Image.Resampling.BILINEAR)
# Out:
# <PIL.Image.Image image mode=RGBA size=98x102>

# %%
im.resize((w//2, h//2), Image.Resampling.BILINEAR)
# Out:
# <PIL.Image.Image image mode=RGB size=98x102>

# %%
im.rotate(45).show()

# %%
im.rotate(180, expand=True, fillcolor="white").show()

# %%
# flip image
im.transpose(Image.TRANSPOSE.FLIP_LEFT_RIGHT).show()
# Out:
# C:\Users\~Mr~amit\AppData\Local\Temp\ipykernel_19000\1290140085.py:2: DeprecationWarning: TRANSPOSE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.TRANSPOSE instead.
#   im.transpose(Image.TRANSPOSE.FLIP_LEFT_RIGHT).show()

# %%
im.transpose(Image.TRANSPOSE.FLIP_TOP_BOTTOM).show()
# Out:
# C:\Users\~Mr~amit\AppData\Local\Temp\ipykernel_19000\2574620906.py:1: DeprecationWarning: TRANSPOSE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.TRANSPOSE instead.
#   im.transpose(Image.TRANSPOSE.FLIP_TOP_BOTTOM).show()

# %%
hero.convert('L').show()

# %%
im2 = Image.open(r"C:\Users\~Mr~amit\Downloads\wp2119153-4k-wallpapers.jpg")
im2.show()

# %%
im.size
# Out:
# (700, 399)

# %%
im2.size
# Out:
# (3840, 2160)

# %%
im2.resize((700, 399))
# Out:
# <PIL.Image.Image image mode=RGB size=700x399>

# %%
im.mode
# Out:
# 'RGB'

# %%
im2 = im2.resize(im.size, Image.Resampling.BILINEAR)
im2 = im2.convert(im.mode)
Image.blend(im,im2, .9).show()

# %%
w,h = im2.size
im2.paste(im2.resize((w//2, h//2)),(w//4, h//4))
im2.show()

# %%
im.paste(im2.resize((300, 300)), (w//4, h//4))
im.show()

# %%
hero
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=196x204>

# %%
# im=(100,100, 200,200)
# Image.crop(im)

# %%
r,g,b = im2.split()
Image.merge('RGB',(b,g,b))
# Out:
# <PIL.Image.Image image mode=RGB size=700x399>

# %%
hero.filter(ImageFilter.BLUR).show()
hero.filter(ImageFilter.CONTOUR).show()
hero.filter(ImageFilter.DETAIL).show()
hero.filter(ImageFilter.EDGE_ENHANCE).show()
hero.filter(ImageFilter.EDGE_ENHANCE_MORE).show()
hero.filter(ImageFilter.EMBOSS).show()
hero.filter(ImageFilter.FIND_EDGES).show()
hero.filter(ImageFilter.SMOOTH).show()
hero.filter(ImageFilter.SMOOTH_MORE).show()
hero.filter(ImageFilter.SHARPEN).show()
hero.filter(ImageFilter.GaussianBlur).show()
